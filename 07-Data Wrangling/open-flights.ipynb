# %% [markdown]
# ### Open Flights Data Wrangling
#
# To practice, you are going to wrangle data from OpenFlights.  You can read about it here:
#
# http://openflights.org/data.html
#
# This includes three main files, one for each airport, one for each airline, and one for each route.  They can be merged or joined with the appropriate fields.  I have modified the files slightly to include a header row in the .dat files, which makes it a bit easier for you.
#
# You are required to work through the problems below.  This may take some time.  Be persistent, and ask questions or seek help as needed.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %% [markdown]
# 1) Start by seeing what's in the data.  What columns are there?  What data types are the columns?
#
# Remember, 'object' means it is a string, while the numerical values can be floats or ints.  Sometimes you will have problems if it reads numeric data in as strings.  If that happens, you can use the function .astype() to convert it.  Look it up in the pandas API to get more details

# %% [markdown]
# ## Answer

# %%
print (airports.dtypes)
airports.head ()
# Out:
# id             int64
# name          object
# city          object
# country       object
# iata          object
# icao          object
# latitude     float64
# longitude    float64
# altitude       int64
# timezone     float64
# dst           object
# tz            object
# type          object
# source        object
# dtype: object
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
print (airlines.dtypes)
airlines.head ()
# Out:
# id           int64
# name        object
# alias       object
# iata        object
# icao        object
# callsign    object
# country     object
# active      object
# dtype: object
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
print (routes.dtypes)
routes.head ()
# Out:
# airline        object
# airline_id    float64
# source         object
# source_id     float64
# dest           object
# dest_id       float64
# codeshare      object
# stops           int64
# equipment      object
# dtype: object
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# 2) Select just the routes that go to or from Lexington Bluegrass Airport, and store them in their own dataframe.
#
# The airport code is LEX.  You should have a much smaller dataframe.  How many inbound routes and how many outbound routes are there?

# %% [markdown]
# ## Answer 2

# %%
#the routes that go to or from Lexington Bluegrass Airport
lex_routes = routes [(routes['source'] == 'LEX') | (routes ['dest'] =='LEX')]
lex_routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 3569       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 4953       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 5247       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6283       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 9097       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 20164      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 20534      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 20638      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 21131      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 21402      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 28951      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 29090      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 29120      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 29187      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 36396      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 56775      UA      5209.0    IAH     3550.0  LEX   4017.0         Y      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 57030      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 57322      UA      5209.0    ORD     3830.0  LEX   4017.0         Y      0
# 58812      US      5265.0    CLT     3876.0  LEX   4017.0       NaN      0
# 59096      US      5265.0    DFW     3670.0  LEX   4017.0       NaN      0
# 59544      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 59545      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 59546      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
# 59924      US      5265.0    ORD     3830.0  LEX   4017.0         Y      0
#
#              equipment
# 3569               CRJ
# 3588               CRJ
# 4953               CR7
# 5247           ERD ER4
# 5763           CR7 CRJ
# 5764           ERD ER4
# 5765           ERD ER4
# 6283           ERD ER4
# 9097   CR9 M88 CRJ 717
# 9641           CRJ CR9
# 20164          M88 717
# 20534              CRJ
# 20638              717
# 21095          M88 717
# 21096              CRJ
# 21097      CR7 CRJ CR9
# 21098              ERJ
# 21099              CRJ
# 21131              ERJ
# 21402              CRJ
# 28951              M80
# 29047              M80
# 29048              M80
# 29049              320
# 29050          M80 320
# 29090              M80
# 29120              320
# 29187          M80 320
# 36396      CR9 M88 CRJ
# 36746          CR9 CRJ
# 56775              ERJ
# 57029              ERJ
# 57030          ERJ CRJ
# 57322          ERJ CRJ
# 58812              CR7
# 59096              ERD
# 59544              CR7
# 59545              ERD
# 59546          ERD ER4
# 59924          ERD ER4

# %% [markdown]
# ### Inbounds are flights to LEX.

# %%
inbound = len (lex_routes [lex_routes['dest'] == 'LEX'])
print ("Inbound route count is " + str(inbound))
# Out:
# Inbound route count is 20

# %% [markdown]
# ### Outbounds are flights from LEX

# %%
outbound = len (lex_routes [lex_routes['source'] == 'LEX'])
print ("Outbound route count is " + str(outbound))
# Out:
# Outbound route count is 20

# %% [markdown]
# 3) Now let's look at which airlines operate in and out of Lexington.  To do this, you need to merge the airline dataframe to the route dataframe.
#
# How many routes does each airline have?  The value_counts() method may be useful for answering this question.

# %% [markdown]
# ## Answer 3

# %%
#merging airline dataframe to the route dataframe
lex_routes_airlines = pd.merge (lex_routes, airlines, left_on = "airline_id", right_on = "id")
lex_routes_airlines
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 1       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 2       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 3       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 4       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 6       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 7       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 8       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 10      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 11      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 12      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 13      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 14      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 15      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 16      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 17      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 18      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 19      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 20      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 21      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 22      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 23      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 24      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 25      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 26      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 27      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 28      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 29      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 30      UA      5209.0    IAH     3550.0  LEX   4017.0         Y      0
# 31      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 32      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 33      UA      5209.0    ORD     3830.0  LEX   4017.0         Y      0
# 34      US      5265.0    CLT     3876.0  LEX   4017.0       NaN      0
# 35      US      5265.0    DFW     3670.0  LEX   4017.0       NaN      0
# 36      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 37      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 38      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
# 39      US      5265.0    ORD     3830.0  LEX   4017.0         Y      0
#
#           equipment    id                      name alias iata icao  \
# 0               CRJ  3976         Pinnacle Airlines   NaN   9E  FLG
# 1               CRJ  3976         Pinnacle Airlines   NaN   9E  FLG
# 2               CR7    24         American Airlines   NaN   AA  AAL
# 3           ERD ER4    24         American Airlines   NaN   AA  AAL
# 4           CR7 CRJ    24         American Airlines   NaN   AA  AAL
# 5           ERD ER4    24         American Airlines   NaN   AA  AAL
# 6           ERD ER4    24         American Airlines   NaN   AA  AAL
# 7           ERD ER4    24         American Airlines   NaN   AA  AAL
# 8   CR9 M88 CRJ 717   137                Air France   NaN   AF  AFR
# 9           CRJ CR9   137                Air France   NaN   AF  AFR
# 10          M88 717  2009           Delta Air Lines   NaN   DL  DAL
# 11              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 12              717  2009           Delta Air Lines   NaN   DL  DAL
# 13          M88 717  2009           Delta Air Lines   NaN   DL  DAL
# 14              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 15      CR7 CRJ CR9  2009           Delta Air Lines   NaN   DL  DAL
# 16              ERJ  2009           Delta Air Lines   NaN   DL  DAL
# 17              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 18              ERJ  2009           Delta Air Lines   NaN   DL  DAL
# 19              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 20              M80    35             Allegiant Air   NaN   G4  AAY
# 21              M80    35             Allegiant Air   NaN   G4  AAY
# 22              M80    35             Allegiant Air   NaN   G4  AAY
# 23              320    35             Allegiant Air   NaN   G4  AAY
# 24          M80 320    35             Allegiant Air   NaN   G4  AAY
# 25              M80    35             Allegiant Air   NaN   G4  AAY
# 26              320    35             Allegiant Air   NaN   G4  AAY
# 27          M80 320    35             Allegiant Air   NaN   G4  AAY
# 28      CR9 M88 CRJ  3090  KLM Royal Dutch Airlines   NaN   KL  KLM
# 29          CR9 CRJ  3090  KLM Royal Dutch Airlines   NaN   KL  KLM
# 30              ERJ  5209           United Airlines   NaN   UA  UAL
# 31              ERJ  5209           United Airlines   NaN   UA  UAL
# 32          ERJ CRJ  5209           United Airlines   NaN   UA  UAL
# 33          ERJ CRJ  5209           United Airlines   NaN   UA  UAL
# 34              CR7  5265                US Airways   NaN   US  USA
# 35              ERD  5265                US Airways   NaN   US  USA
# 36              CR7  5265                US Airways   NaN   US  USA
# 37              ERD  5265                US Airways   NaN   US  USA
# 38          ERD ER4  5265                US Airways   NaN   US  USA
# 39          ERD ER4  5265                US Airways   NaN   US  USA
#
#      callsign        country active
# 0    FLAGSHIP  United States      Y
# 1    FLAGSHIP  United States      Y
# 2    AMERICAN  United States      Y
# 3    AMERICAN  United States      Y
# 4    AMERICAN  United States      Y
# 5    AMERICAN  United States      Y
# 6    AMERICAN  United States      Y
# 7    AMERICAN  United States      Y
# 8    AIRFRANS         France      Y
# 9    AIRFRANS         France      Y
# 10      DELTA  United States      Y
# 11      DELTA  United States      Y
# 12      DELTA  United States      Y
# 13      DELTA  United States      Y
# 14      DELTA  United States      Y
# 15      DELTA  United States      Y
# 16      DELTA  United States      Y
# 17      DELTA  United States      Y
# 18      DELTA  United States      Y
# 19      DELTA  United States      Y
# 20  ALLEGIANT  United States      Y
# 21  ALLEGIANT  United States      Y
# 22  ALLEGIANT  United States      Y
# 23  ALLEGIANT  United States      Y
# 24  ALLEGIANT  United States      Y
# 25  ALLEGIANT  United States      Y
# 26  ALLEGIANT  United States      Y
# 27  ALLEGIANT  United States      Y
# 28        KLM    Netherlands      Y
# 29        KLM    Netherlands      Y
# 30     UNITED  United States      Y
# 31     UNITED  United States      Y
# 32     UNITED  United States      Y
# 33     UNITED  United States      Y
# 34    U S AIR  United States      Y
# 35    U S AIR  United States      Y
# 36    U S AIR  United States      Y
# 37    U S AIR  United States      Y
# 38    U S AIR  United States      Y
# 39    U S AIR  United States      Y

# %%
#Number of routes each airlines has
lex_routes_airlines['name'].value_counts()
# Out:
# Delta Air Lines             10
# Allegiant Air                8
# US Airways                   6
# American Airlines            6
# United Airlines              4
# Air France                   2
# KLM Royal Dutch Airlines     2
# Pinnacle Airlines            2
# Name: name, dtype: int64

# %% [markdown]
# 4) It looks like there are some international airlines with Lexington routes.  To look at how many routes they have, create a new column in your dataframe called 'International', which is set to Y for an overseas airline and N for a domestic airline.  Calculate the percent of routes with an overseas airline.

# %% [markdown]
# ## Answer 4

# %%
international = []

for domestic in lex_routes_airlines ['country']:
    if domestic == 'United States':
        international.append ('N')
    else:
        international.append ('Y')

intl_airline_LEX = lex_routes_airlines.assign(International=international)
intl_airline_LEX
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 1       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 2       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 3       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 4       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 6       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 7       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 8       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 10      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 11      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 12      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 13      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 14      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 15      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 16      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 17      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 18      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 19      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 20      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 21      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 22      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 23      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 24      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 25      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 26      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 27      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 28      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 29      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 30      UA      5209.0    IAH     3550.0  LEX   4017.0         Y      0
# 31      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 32      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 33      UA      5209.0    ORD     3830.0  LEX   4017.0         Y      0
# 34      US      5265.0    CLT     3876.0  LEX   4017.0       NaN      0
# 35      US      5265.0    DFW     3670.0  LEX   4017.0       NaN      0
# 36      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 37      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 38      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
# 39      US      5265.0    ORD     3830.0  LEX   4017.0         Y      0
#
#           equipment    id                      name alias iata icao  \
# 0               CRJ  3976         Pinnacle Airlines   NaN   9E  FLG
# 1               CRJ  3976         Pinnacle Airlines   NaN   9E  FLG
# 2               CR7    24         American Airlines   NaN   AA  AAL
# 3           ERD ER4    24         American Airlines   NaN   AA  AAL
# 4           CR7 CRJ    24         American Airlines   NaN   AA  AAL
# 5           ERD ER4    24         American Airlines   NaN   AA  AAL
# 6           ERD ER4    24         American Airlines   NaN   AA  AAL
# 7           ERD ER4    24         American Airlines   NaN   AA  AAL
# 8   CR9 M88 CRJ 717   137                Air France   NaN   AF  AFR
# 9           CRJ CR9   137                Air France   NaN   AF  AFR
# 10          M88 717  2009           Delta Air Lines   NaN   DL  DAL
# 11              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 12              717  2009           Delta Air Lines   NaN   DL  DAL
# 13          M88 717  2009           Delta Air Lines   NaN   DL  DAL
# 14              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 15      CR7 CRJ CR9  2009           Delta Air Lines   NaN   DL  DAL
# 16              ERJ  2009           Delta Air Lines   NaN   DL  DAL
# 17              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 18              ERJ  2009           Delta Air Lines   NaN   DL  DAL
# 19              CRJ  2009           Delta Air Lines   NaN   DL  DAL
# 20              M80    35             Allegiant Air   NaN   G4  AAY
# 21              M80    35             Allegiant Air   NaN   G4  AAY
# 22              M80    35             Allegiant Air   NaN   G4  AAY
# 23              320    35             Allegiant Air   NaN   G4  AAY
# 24          M80 320    35             Allegiant Air   NaN   G4  AAY
# 25              M80    35             Allegiant Air   NaN   G4  AAY
# 26              320    35             Allegiant Air   NaN   G4  AAY
# 27          M80 320    35             Allegiant Air   NaN   G4  AAY
# 28      CR9 M88 CRJ  3090  KLM Royal Dutch Airlines   NaN   KL  KLM
# 29          CR9 CRJ  3090  KLM Royal Dutch Airlines   NaN   KL  KLM
# 30              ERJ  5209           United Airlines   NaN   UA  UAL
# 31              ERJ  5209           United Airlines   NaN   UA  UAL
# 32          ERJ CRJ  5209           United Airlines   NaN   UA  UAL
# 33          ERJ CRJ  5209           United Airlines   NaN   UA  UAL
# 34              CR7  5265                US Airways   NaN   US  USA
# 35              ERD  5265                US Airways   NaN   US  USA
# 36              CR7  5265                US Airways   NaN   US  USA
# 37              ERD  5265                US Airways   NaN   US  USA
# 38          ERD ER4  5265                US Airways   NaN   US  USA
# 39          ERD ER4  5265                US Airways   NaN   US  USA
#
#      callsign        country active International
# 0    FLAGSHIP  United States      Y             N
# 1    FLAGSHIP  United States      Y             N
# 2    AMERICAN  United States      Y             N
# 3    AMERICAN  United States      Y             N
# 4    AMERICAN  United States      Y             N
# 5    AMERICAN  United States      Y             N
# 6    AMERICAN  United States      Y             N
# 7    AMERICAN  United States      Y             N
# 8    AIRFRANS         France      Y             Y
# 9    AIRFRANS         France      Y             Y
# 10      DELTA  United States      Y             N
# 11      DELTA  United States      Y             N
# 12      DELTA  United States      Y             N
# 13      DELTA  United States      Y             N
# 14      DELTA  United States      Y             N
# 15      DELTA  United States      Y             N
# 16      DELTA  United States      Y             N
# 17      DELTA  United States      Y             N
# 18      DELTA  United States      Y             N
# 19      DELTA  United States      Y             N
# 20  ALLEGIANT  United States      Y             N
# 21  ALLEGIANT  United States      Y             N
# 22  ALLEGIANT  United States      Y             N
# 23  ALLEGIANT  United States      Y             N
# 24  ALLEGIANT  United States      Y             N
# 25  ALLEGIANT  United States      Y             N
# 26  ALLEGIANT  United States      Y             N
# 27  ALLEGIANT  United States      Y             N
# 28        KLM    Netherlands      Y             Y
# 29        KLM    Netherlands      Y             Y
# 30     UNITED  United States      Y             N
# 31     UNITED  United States      Y             N
# 32     UNITED  United States      Y             N
# 33     UNITED  United States      Y             N
# 34    U S AIR  United States      Y             N
# 35    U S AIR  United States      Y             N
# 36    U S AIR  United States      Y             N
# 37    U S AIR  United States      Y             N
# 38    U S AIR  United States      Y             N
# 39    U S AIR  United States      Y             N

# %%
intl_airline_LEX ['International'].value_counts ()
# Out:
# N    36
# Y     4
# Name: International, dtype: int64

# %%
intl = intl_airline_LEX[intl_airline_LEX ['International']=='Y']
total = intl_airline_LEX['International']

percentage = (len (intl)/len (total))*100

print('Percentage of overseas flights:' + str (percentage) + "%" )
# Out:
# Percentage of overseas flights:10.0%

# %% [markdown]
# 5) Actually, it looks like a bunch of these routes are codeshares.  That means they are marketed by this airline, but operated by a different airline.  See the note in the data documentation on openflights.org/data.  The implication of this is that there are duplicates.
#
# Can you figure out which ones are duplicates?  Can you then create a dataframe with only the unique routes?  How many unique inbound and outbound routes are there?
#
# Remember, someone has to operate the flight, so if all the routes to/from a particular airport are listed as codeshares, then something is funny...
#
# It is also possible that more than one airline actually operates a route between the same two airports. (Having this sort of competition generally means that you will get better fares as a traveler.)  It may not be obvious what is actually in the data set, so dig or do external research as needed.

# %% [markdown]
# ## Answer 5

# %%
# Dataframes with duplicates
lex_duplicates = lex_routes [lex_routes['codeshare'] == 'Y']
lex_duplicates
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 5247       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6283       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 9097       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 20534      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 21131      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 21402      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 36396      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 56775      UA      5209.0    IAH     3550.0  LEX   4017.0         Y      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 57030      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 57322      UA      5209.0    ORD     3830.0  LEX   4017.0         Y      0
# 59546      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
# 59924      US      5265.0    ORD     3830.0  LEX   4017.0         Y      0
#
#              equipment
# 5247           ERD ER4
# 5763           CR7 CRJ
# 5764           ERD ER4
# 5765           ERD ER4
# 6283           ERD ER4
# 9097   CR9 M88 CRJ 717
# 9641           CRJ CR9
# 20534              CRJ
# 21096              CRJ
# 21097      CR7 CRJ CR9
# 21099              CRJ
# 21131              ERJ
# 21402              CRJ
# 36396      CR9 M88 CRJ
# 36746          CR9 CRJ
# 56775              ERJ
# 57029              ERJ
# 57030          ERJ CRJ
# 57322          ERJ CRJ
# 59546          ERD ER4
# 59924          ERD ER4

# %%
#Dataframe with uniques
lex_uniques = lex_routes [lex_routes['codeshare'] != 'Y']
lex_uniques
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 3569       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 4953       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 20164      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 20638      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 28951      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 29090      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 29120      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 29187      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 58812      US      5265.0    CLT     3876.0  LEX   4017.0       NaN      0
# 59096      US      5265.0    DFW     3670.0  LEX   4017.0       NaN      0
# 59544      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 59545      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
#
#       equipment
# 3569        CRJ
# 3588        CRJ
# 4953        CR7
# 20164   M88 717
# 20638       717
# 21095   M88 717
# 21098       ERJ
# 28951       M80
# 29047       M80
# 29048       M80
# 29049       320
# 29050   M80 320
# 29090       M80
# 29120       320
# 29187   M80 320
# 58812       CR7
# 59096       ERD
# 59544       CR7
# 59545       ERD

# %%
lex_unique_inbound = lex_routes [(lex_routes['codeshare'] != 'Y') & (lex_routes['dest']== 'LEX')]
print ("Unique Inbound is:" + str (len (lex_unique_inbound)))
# Out:
# Unique Inbound is:10

# %%
lex_unique_outbound = lex_routes [(lex_routes['codeshare'] != 'Y') & (lex_routes['source']== 'LEX')]
print ("Unique Outbound is:" + str (len (lex_unique_outbound)))
# Out:
# Unique Outbound is:9
